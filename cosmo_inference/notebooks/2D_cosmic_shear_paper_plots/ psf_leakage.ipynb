# %% [markdown]
# ## PSF Leakage Plots
#
# This notebook creates all the plots of the PSF leakage: the $\rho$ and $\tau$ statistics (from Guerrini et al. 2024) as well as the covariance matrix of the $\alpha_{PSF}$ and $\beta_{PSF}$ parameters.
