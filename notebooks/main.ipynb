# %%
# Weak-lensing galaxy shape catalogue validation

## Main notebook

# %%
import os

# %%
# Path to sp_validation package
sp_base= f"{os.environ['HOME']}/astro/repositories/github/sp_validation"

# %%
# Load parameters
# %run params.py
# Out:
# Field name = W3

# %%
# Run further notebooks here:
# In jupyter-lab open a notebook, then change the kernel to main.ipybn.

# %%
# Run the following notebooks in order:
# 1. set_up_data_match_select.ipybn
# 2. metacal_global.ipynb
# 3. psf_leakage.ipybn
# 4. write_cat.ipybn
# 5. cosmology.ipybn

# %%
# This opens the file in another browser tab, not a tab within jupyer-lab.
# %%javascript
#window.open('http://localhost:8888/notebooks/set_up_data_match_select.ipynb')
